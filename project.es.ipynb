# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
print(ds.head())
# Out:
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 1           2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 1       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 2       916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 3       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 4       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
#
#    bathrooms  surface   price  ... level4Id level5Id level6Id level7Id  \
# 0        2.0    103.0  195000  ...        0        0        0        0
# 1        1.0      NaN   89000  ...        0        0        0        0
# 2        2.0     99.0  390000  ...        0        0        0        0
# 3        1.0     86.0   89000  ...        0        0        0        0
# 4        2.0    106.0  172000  ...        0        0        0        0
#
#   level8Id accuracy          latitude          longitude zipCode customZone
# 0        0        0  40,2948276786438  -3,44402412135624     NaN        NaN
# 1        0        1          40,28674           -3,79351     NaN        NaN
# 2        0        0  40,4115646786438  -3,90662252135624     NaN        NaN
# 3        0        0  40,2853785786438  -3,79508142135624     NaN        NaN
# 4        0        0  40,2998774864376  -3,45226301356237     NaN        NaN
#
# [5 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
import numpy as np
indice_max = np.argmax(ds["price"])
print("La casa con dirección en " + ds.loc[indice_max,"address"] + " es la más cara y su precio es de " + str(ds.loc[indice_max, "price"]))
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO
indice_min = np.argmin(ds["price"])
print("La casa con dirección en " + ds.loc[indice_min,"address"] + " es la más barata y su precio es de " + str(ds.loc[indice_min, "price"]))
# Out:
# La casa con dirección en Parla es la más barata y su precio es de 0

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO
indice_grande = np.argmax(ds["surface"])
indice_peque = np.argmin(ds["surface"])
print("La casa más grande está ubicada en " + ds.loc[indice_grande,"address"] + " y su superficie es de " + str(ds.loc[indice_grande, "surface"]) + " metros")
print("La casa más pequeña está ubicada en " + ds.loc[indice_peque,"address"] + " y su superficie es de " + str(ds.loc[indice_peque, "surface"]) + " metros")
# Out:
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO
poblaciones = ds["level5"].unique()
num_poblaciones = len(poblaciones)
print("Cantidad de poblaciones: " + str(num_poblaciones))
print(", ".join(poblaciones))
# Out:
# Cantidad de poblaciones: 168
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bustarviejo, Manzanares El Real, Carabaña, Casarrubuelos, Cercedilla, Fresnedillas de la Oliva, Valdemaqueda, Robledo de Chavela, Miraflores de la Sierra, Humanes de Madrid, Valdetorres de Jarama, San Agustín del Guadalix, Ciempozuelos, Camarma de Esteruelas, Torres de la Alameda, Talamanca de Jarama, El Atazar, Hoyo de Manzanares, El Boalo - Cerceda – Mataelpino, El Álamo, Valdilecha, Valdeolmos-Alalpardo, Guadalix de la Sierra, Belmonte de Tajo, El Vellón, Brunete, Redueña, Morata de Tajuña, Tielmes, Gargantilla del Lozoya, Meco, Venturada, Quijorna, Cenicientos, Torrejón de Velasco, Navacerrada, Santa María de la Alameda, Orusco de Tajuña, Daganzo de Arriba, Villamanta, Anchuelo, Valdaracete, Ajalvir, Los Santos de la Humosa, Villamanrique de Tajo, Colmenar de Oreja, Villa del Prado, Fuentidueña de Tajo, Colmenar del Arroyo, Valdelaguna, Cubas de la Sagra, Valdeavero, Aldea del Fresno, Ribatejada, Torrelaguna, Batres, Pezuela de las Torres, Colmenarejo, Serranillos del Valle, Cobeña, Soto del Real, El Berrueco, Villanueva de Perales, Fresno de Torote - Serracines, Pozuelo del Rey, Pelayos de la Presa, La Cabrera, Nuevo Baztán, Perales de Tajuña, Villaconejos, Villarejo de Salvanés, Cadalso de los Vidrios, Santorcaz, Madarcos, Garganta de los Montes, Puentes Viejas, Torremocha de Jarama, Valdemanco, Braojos, Lozoyuela-navas-sieteiglesias, Piñuécar-gandullas, Valdepiélagos, Valverde de Alcalá, Villar del Olmo, Villamantilla, Horcajo de la Sierra, Gascones, Zarzalejo, Villavieja del Lozoya, Brea de Tajo, Estremera, Chapinería, Navarredonda, Patones, Ambite, Navalafuente, Lozoya, Canencia, Cabanillas de la Sierra, Buitrago del Lozoya, Fresno de Torote, Robregordo, Pinilla del Valle, Rascafría, La Hiruela, Montejo de la Sierra

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
## Algun NA en el dataset?
print(ds.isnull().values.any())
## Algun NA columna por columna
print(ds.isnull().any())
##Algun NA fila por fila
print(ds.isnull().any(axis=1))
# Out:
# True
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# zipCode              True
# customZone           True
# dtype: bool
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15330    True
# 15331    True
# 15332    True
# 15333    True
# 15334    True
# Length: 15335, dtype: bool

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO
dimension_original = ds.shape
ds_limpio = ds.dropna(axis=1, how="all")
dimension_limpio = ds_limpio.shape
print(f"Dimensiones originales: {dimension_original}")
print(f"Dimensiones después de las eliminaciones: {dimension_limpio}")
# Out:
# Dimensiones originales: (15335, 37)
# Dimensiones después de las eliminaciones: (15335, 35)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO
filtro_arroyomolinos = ds[ds["level5"] == "Arroyomolinos (Madrid)"]
media_precios_arromoli = filtro_arroyomolinos["price"].mean()
print(f"La media de precios en Arroyomolinos es: {media_precios_arromoli}")
# Out:
# La media de precios en Arroyomolinos es: 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import matplotlib.pyplot as plt
plt.figure(figsize = (10, 5))
plt.hist(filtro_arroyomolinos["price"], bins = 30, alpha = 0.7)
plt.title("Histograma precios Arroyomolinos")
plt.xlabel("Precio")
plt.show()

# %% [markdown]
# En el histograma de los precios en Arroyomolinos, se puede observar que la mayor parte de los precios se encuentran en el tramo entre los 200000 y los 400000 con el pico más alto algo por debajo de los 300000.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO
filtro_valdemorillo = ds[ds["level5"] == "Valdemorillo"]
filtro_galapagar = ds[ds["level5"] == "Galapagar"]
media_precios_valdemorillo = filtro_valdemorillo["price"].mean()
media_precios_galapagar = filtro_galapagar["price"].mean()
print(f"La media de precios en Valdemorillo es: {media_precios_valdemorillo} y en Galapagar es: {media_precios_galapagar}")
# Out:
# La media de precios en Valdemorillo es: 363860.2931034483 y en Galapagar es: 360063.20238095237

# %% [markdown]
# Observando la media de precios de Valdemorillo y Galapagar, se podría decir que son prácticamente iguales.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO
ds["pps"] = ds["price"].div(ds["surface"])
filtro_valdemorillo = ds[ds["level5"] == "Valdemorillo"]
filtro_galapagar = ds[ds["level5"] == "Galapagar"]
media_pps_valdemorillo = filtro_valdemorillo["pps"].mean()
media_pps_galapagar = filtro_galapagar["pps"].mean()
print(f"La media de precio/m2 de Valdemorillo es: {media_pps_valdemorillo} y la de Galapagar es: {media_pps_galapagar}")
# Out:
# La media de precio/m2 de Valdemorillo es: 1317.9502109024986 y la de Galapagar es: 1606.3240303094024

# %% [markdown]
# Las medias presentan una diferencia de 300, lo que implica que de media, en Valdemorillo es más barato el precio/m2.

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# TODO: Código
plt.figure(figsize=(10,5))
plt.scatter(ds["surface"], ds["price"])
plt.xlim(0, 3000)
plt.title("Relación superficie-precio")
plt.xlabel('Superficie')
plt.ylabel('Precio')
plt.show()

plt.figure(figsize=(10,5))
plt.scatter(filtro_galapagar["surface"], filtro_galapagar["price"])
plt.xlim(0, 2000)
plt.title("Relación superficie-precio Galapagar")
plt.xlabel('Superficie')
plt.ylabel('Precio')
plt.show()

# %% [markdown]
# En el gráfico de Relación superficie-precio Galapagar, se puede observar la correlación positiva entre la superficie y el precio de las casas. Sin embargo, en el gráfico general, esta relación no se ve tan clara ya que, el precio de las casas se ve influenciado por otros factores como la población en la que se encuentra.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO
agencias = ds["realEstate_name"].unique()
print(f"{len(agencias)} agencias de bienes raíces")
# Out:
# 1822 agencias de bienes raíces

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO
conteo_casas = ds.groupby(ds["level5"]).size().sort_values(ascending=False)
print(conteo_casas.head(1))
# Out:
# level5
# Madrid Capital    6643
# dtype: int64

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO
cinturon_sur = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
ds_sur = ds[ds["level5"].isin(cinturon_sur)]
print(ds_sur.head())
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 85           86       153152077  False            sinergical inmobiliaria
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
#
#      phone_realEstate                                       url_inmueble  \
# 1         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3         916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94        911226014.0  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109       912664081.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price  ... level5Id level6Id level7Id  \
# 1      3.0        1.0      NaN   89000  ...        0        0        0
# 3      3.0        1.0     86.0   89000  ...        0        0        0
# 85     1.0        1.0     50.0  107000  ...        0        0        0
# 94     3.0        2.0    120.0  320000  ...        0        0        0
# 109    3.0        3.0    142.0  425000  ...        0        0        0
#
#     level8Id accuracy          latitude          longitude zipCode customZone  \
# 1          0        1          40,28674           -3,79351     NaN        NaN
# 3          0        0  40,2853785786438  -3,79508142135624     NaN        NaN
# 85         0        1          40,35059           -3,82693     NaN        NaN
# 94         0        0          40,31933           -3,77574     NaN        NaN
# 109        0        0        40,3313411         -3,8313868     NaN        NaN
#
#              pps
# 1            NaN
# 3    1034.883721
# 85   2140.000000
# 94   2666.666667
# 109  2992.957746
#
# [5 rows x 38 columns]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: Code
mediana_precios_sur = ds_sur.groupby("level5")["price"].median()
plt.figure(figsize = (10,5))
plt.bar(mediana_precios_sur.index, mediana_precios_sur.values)
plt.xlabel("Población")
plt.ylabel("Mediana del Precio")
plt.show()

# %% [markdown]
# La mediana representa el valor central. Getafe tiene la mediana de precios más alta entre las poblaciones, superando los 250000, mientras que Fuenlabrada presenta la mediana más baja. Esto sugiere que, Getafe es la población con los precios más altos de las cuatro.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO
def media_var (variable, dataset):
    calc_media = dataset[variable].mean()
    calc_varianza = dataset[variable].var()
    print(f"{variable}: La media es {calc_media} y la varianza es {calc_varianza}")
    return None
variables = ["price", "rooms", "surface", "bathrooms"]
for i in variables:
    media_var(i,ds_sur)
# Out:
# price: La media es 223094.48070562293 y la varianza es 14921367508.04902
# rooms: La media es 3.0177383592017737 y la varianza es 0.7188858892927542
# surface: La media es 111.75222363405337 y la varianza es 4263.051760316337
# bathrooms: La media es 1.633221850613155 y la varianza es 0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO
indices_max_precios = ds_sur.groupby("level5")["price"].idxmax()
casas_caras = ds_sur.loc[indices_max_precios]
print(casas_caras[["level5","address", "price"]])
# Out:
#             level5                                address    price
# 5585      Alcorcón                               Alcorcón   950000
# 11561  Fuenlabrada  Calle de Paulo Freire, 5, Fuenlabrada   490000
# 2881        Getafe                                 Getafe  1050000
# 10412      Leganés           Avenida Reina Sofía, Leganés   650000

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
poblaciones_sur = ds_sur["level5"].unique()

# Crear un gráfico con múltiples histogramas
plt.figure(figsize=(10, 6))

# Recorrer las poblaciones y crear un histograma normalizado para cada una
for poblacion in poblaciones_sur:
    # Filtrar los precios para la población
    precios = ds_sur[ds_sur["level5"] == poblacion]["price"]
    
    # Normalizar los precios (min-max normalization)
    media = precios.mean()
    desviacion_estandar = precios.std()
    precios_normalizados = (precios - media) / desviacion_estandar
    
    # Traza el histograma de los precios normalizados
    plt.hist(precios_normalizados, bins=20, alpha=0.5, label=f'Población: {poblacion}')

# Añadir leyenda, título y etiquetas
plt.legend(loc="upper right")
plt.title("Histogramas de precios normalizados por población")
plt.xlabel("Precio Normalizado")

# Mostrar el gráfico
plt.show()

# %% [markdown]
# La normalización permite comparar las distribuciones de precios entre las poblaciones de forma directa, sin verse afectadas por las diferencias de escala.
# En general, todas las poblaciones muestran una concentración en precios bajos, destacando Getafe con ese pico en torno al -1.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO
filtro_getafe = ds_sur[ds_sur["level5"] == "Getafe"]
filtro_alcorcon = ds_sur[ds_sur["level5"] == "Alcorcón"]
pps_getafe = filtro_getafe["pps"]
pps_alcorcon = filtro_alcorcon["pps"]
print(f"Precios por metro cuadrado en Getafe:\n{pps_getafe}")
print("\n--------------------------\n")
print(f"Precios por metro cuadrado en Alcorcón:\n{pps_alcorcon}")
print("\n--------------------------\n")
media_pps_getafe = filtro_getafe["pps"].mean()
media_pps_alcorcon = filtro_alcorcon["pps"].mean()
print(f"El precio medio por metro cuadrado en Getafe es: {media_pps_getafe}")
print(f"El precio medio por metro cuadrado en Alcorcón es: {media_pps_alcorcon}")
# Out:
# Precios por metro cuadrado en Getafe:
# 169      1487.179487
# 232      2113.846154
# 233      1632.530120
# 269      1611.290323
# 381      1625.000000
#             ...
# 14999    1738.095238
# 15002    2331.893443
# 15034    3262.773723
# 15087    3097.043478
# 15117    2946.428571
# Name: pps, Length: 290, dtype: float64
#
# --------------------------
#
# Precios por metro cuadrado en Alcorcón:
# 85       2140.000000
# 109      2992.957746
# 765      2275.229358
# 816      3114.583333
# 827      1844.615385
#             ...
# 14896    2076.923077
# 15144    3548.387097
# 15166    2397.260274
# 15191    3117.647059
# 15223    3023.529412
# Name: pps, Length: 190, dtype: float64
#
# --------------------------
#
# El precio medio por metro cuadrado en Getafe es: 2066.314949251463
# El precio medio por metro cuadrado en Alcorcón es: 2239.302480199618

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO
fig, axis = plt.subplots(2, 2, figsize=(12, 10))
for i, poblacion in enumerate(cinturon_sur):
    pobl_filtro = ds_sur[ds_sur["level5"] == poblacion]
    precios = pobl_filtro["price"]
    superficie = pobl_filtro["surface"]
    row, col = i // 2, i % 2
    axis[row, col].scatter(superficie, precios)
    axis[row, col].set_title(f"Relación precio-superficie en {poblacion}")
    axis[row, col].set_xlabel("Superficie")
    axis[row, col].set_ylabel("Precio")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps, CircleMarker, LayerGroup

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (40.4168, -3.7038), zoom = 10, min_zoom = 1, max_zoom = 20, basemap=basemaps.OpenStreetMap.Mapnik)
map
# Out:
# Map(center=[40.4168, -3.7038], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:

# Convertir las coordenadas de comas a puntos
ds_sur['latitude'] = ds_sur['latitude'].str.replace(',', '.').astype(float)
ds_sur['longitude'] = ds_sur['longitude'].str.replace(',', '.').astype(float)

# Crear el diccionario de coordenadas por población
coordenadas_dict = {}
for _, fila in ds_sur.iterrows():
    poblacion = fila['level5']
    coordenada = (fila['latitude'], fila['longitude'])
    if poblacion not in coordenadas_dict:
        coordenadas_dict[poblacion] = []
    coordenadas_dict[poblacion].append(coordenada)

# Asignar colores distintos a cada población
colores = {
    'Getafe': 'blue',
    'Leganés': 'red',
    'Alcorcón': 'green',
    'Fuenlabrada': 'purple',
    'Parla': 'orange'
}

# Crear CircleMarkers usando el diccionario
circulos = []
for poblacion, coordenadas in coordenadas_dict.items():
    for lat, lon in coordenadas:
        circulo = CircleMarker(location=(lat, lon),
                               radius=5,  
                               color=colores.get(poblacion),  
                               fill_color=colores.get(poblacion),  
                               fill_opacity=0.7,  
                               weight=2) 
        circulos.append(circulo)

# Añadir los CircleMarkers en un grupo de capas y al mapa
layer_group = LayerGroup(layers=circulos)
map.add_layer(layer_group)

map
# Out:
# /tmp/ipykernel_594/456852931.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_sur['latitude'] = ds_sur['latitude'].str.replace(',', '.').astype(float)
# /tmp/ipykernel_594/456852931.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_sur['longitude'] = ds_sur['longitude'].str.replace(',', '.').astype(float)
# Map(bottom=99045.0, center=[40.4168, -3.7038], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoo…
